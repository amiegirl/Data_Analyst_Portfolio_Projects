# %% [markdown]
# # EMPOVATION SQL CHALLENGE

# %%
#pip install ipython-sql

# %%
#pip install SQLAlchemy

# %%
#pip install pymysql

# %%
# %load_ext sql

# %%
# %%sql
#
# sqlite:///sample_empovation_.db

# %% [markdown]
# # Data Cleaning

# %%
# %%sql
# --clean UnitPriceUSD column to get rid of the $ and ,
# UPDATE Products
# SET UnitPriceUSD = CAST(REPLACE(REPLACE(UnitPriceUSD,'$',''),',','') as decimal);

# %%
# %%sql
# --clean UnitCostUSD column to get rid of the $ and ,
# UPDATE Products
# SET UnitCostUSD = CAST(REPLACE(REPLACE(UnitCostUSD,'$',''),',','') as decimal);

# %% [markdown]
# **1. Count the Total Orders. Write a query to count the Total Number of Orders Per Customer order in desc**

# %%
# %%sql
# --1.count total orders per customer
# SELECT DISTINCT CustomerKey,
# count(*) as total_orders
# FROM Sales
# GROUP by CustomerKey
# LIMIT 50;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(301, 1),
#  (325, 10),
#  (554, 4),
#  (1042, 3),
#  (1314, 5),
#  (1568, 9),
#  (1585, 4),
#  (1626, 4),
#  (1642, 1),
#  (1863, 8),
#  (2238, 3),
#  (2248, 2),
#  (2435, 4),
#  (2469, 2),
#  (2512, 5),
#  (2792, 1),
#  (3002, 3),
#  (3203, 8),
#  (3327, 3),
#  (3575, 1),
#  (3964, 1),
#  (4174, 5),
#  (5097, 1),
#  (5445, 1),
#  (5962, 8),
#  (6258, 3),
#  (6308, 3),
#  (7109, 2),
#  (7566, 3),
#  (7700, 1),
#  (7783, 1),
#  (8098, 3),
#  (8181, 2),
#  (8789, 2),
#  (8945, 3),
#  (9167, 1),
#  (9184, 4),
#  (9456, 8),
#  (9812, 6),
#  (9915, 4),
#  (10039, 1),
#  (10299, 2),
#  (10393, 1),
#  (11035, 1),
#  (12160, 9),
#  (12365, 2),
#  (12392, 6),
#  (12649, 1),
#  (12729, 6),
#  (12859, 2)]

# %% [markdown]
# **2. List of Products. Write a SQL query to List of Products Sold in 2020**

# %%
# %%sql
# --2.list of sold in 2020
# SELECT DISTINCT ProductName
# FROM Products
# LEFT JOIN Sales on Products.ProductKey = Sales.ProductKey
# WHERE OrderDate like '%2020%'
# LIMIT 50;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Contoso 512MB MP3 Player E51 Silver',),
#  ('Contoso 512MB MP3 Player E51 Blue',),
#  ('Contoso 1G MP3 Player E100 White',),
#  ('Contoso 2G MP3 Player E200 Silver',),
#  ('Contoso 2G MP3 Player E200 Red',),
#  ('Contoso 2G MP3 Player E200 Black',),
#  ('Contoso 2G MP3 Player E200 Blue',),
#  ('Contoso 4G MP3 Player E400 Silver',),
#  ('Contoso 4G MP3 Player E400 Black',),
#  ('Contoso 4G MP3 Player E400 Green',),
#  ('Contoso 4G MP3 Player E400 Orange',),
#  ('Contoso 4GB Flash MP3 Player E401 Blue',),
#  ('Contoso 4GB Flash MP3 Player E401 Black',),
#  ('Contoso 4GB Flash MP3 Player E401 Silver',),
#  ('Contoso 4GB Flash MP3 Player E401 White',),
#  ('Contoso 8GB Super-Slim MP3/Video Player M800 White',),
#  ('Contoso 8GB Super-Slim MP3/Video Player M800 Red',),
#  ('Contoso 8GB Super-Slim MP3/Video Player M800 Green',),
#  ('Contoso 8GB Super-Slim MP3/Video Player M800 Pink',),
#  ('Contoso 8GB MP3 Player new model M820 Black',),
# ...

# %% [markdown]
# **3. Find Customers in a Specific City. Write a query to find all Customer Details from California (CA)**

# %%
# %%sql
# --3.find all customer details from California
# SELECT *
# FROM Customers
# WHERE State = 'California'
# LIMIT 50;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(1200334, 'Male', 'Micheal Boyers', 'Los Angeles', 'CA', 'California', 90017, 'United States', 'North America', '9/30/1989'),
#  (1200992, 'Female', 'Alice Payton', 'Los Angeles', 'CA', 'California', 90017, 'United States', 'North America', '12/3/1952'),
#  (1201225, 'Male', 'John Lally', 'Irvine', 'CA', 'California', 92614, 'United States', 'North America', '2/6/1996'),
#  (1202046, 'Male', 'Scott Webb', 'Walnut Creek', 'CA', 'California', 94596, 'United States', 'North America', '12/13/1993'),
#  (1203201, 'Female', 'Maria Schroyer', 'Dublin', 'CA', 'California', 94568, 'United States', 'North America', '2/26/2001'),
#  (1203510, 'Female', 'Allison Flores', 'Los Angeles', 'CA', 'California', 90071, 'United States', 'North America', '4/25/1954'),
#  (1204360, 'Male', 'Eric Arnold', 'San Jose', 'CA', 'California', 95134, 'United States', 'North America', '4/11/1982'),
# ...

# %% [markdown]
# **4. Calculate Total Sales Quantity. Write a query to calculate the Total Sales Quantity for product 2115**

# %%
# %%sql
# --4.calculate total sales quantity for product 2115
# SELECT sum(Quantity) as tot_sales_qty_p2115
# FROM Sales
# LEFT JOIN Products on Products.ProductKey = Sales.ProductKey
# WHERE Sales.ProductKey = '2115';
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(127,)]

# %% [markdown]
# **5. Store Information Retrieval. Write a query to retrieve the Top 5 Stores with the Most Sales Transactions.**

# %%
# %%sql
# --5.top 5 stores with most sales Transactions
# WITH all_stores as(
# 				SELECT *
# 				FROM Sales
# 				LEFT JOIN Stores on Stores.StoreKey = Sales.StoreKey)
# SELECT StoreKey, sum(Quantity) as total_transactions
# FROM all_stores
# GROUP by StoreKey
# ORDER by total_transactions DESC
# LIMIT 5
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(0, 41311), (9, 4894), (55, 4826), (50, 4773), (61, 4771)]

# %% [markdown]
# **6. Average Price of Products in a Category. Write a query to find the average unit price of products in each category**

# %%
# %%sql
# --6. Average price of Products in each Category
# SELECT Category,
# 		round(avg(UnitPriceUSD)) 'average_price($)'
# FROM Products
# GROUP by Category;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Audio', 136.0),
#  ('Cameras and camcorders', 400.0),
#  ('Cell phones', 175.0),
#  ('Computers', 332.0),
#  ('Games and Toys', 43.0),
#  ('Home Appliances', 538.0),
#  ('Music, Movies and Audio Books', 108.0),
#  ('TV and Video', 498.0)]

# %% [markdown]
# **7. Customer Purchases by Gender. Write a query to count the number of orders placed by each gender**

# %%
# %%sql
# --7.no of orders placed by each Gender
# SELECT Gender,
# 		count(distinct OrderNumber) as total_orders
# FROM Customers as c
# LEFT JOIN Sales as s
# on c.CustomerKey = s.CustomerKey
# GROUP by Gender;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Female', 12970), ('Male', 13356)]

# %% [markdown]
# **8. List of Products Not Sold. Write a query to list all products that have never been sold.**

# %%
# %%sql
# --8. list of products that has never been sold
# SELECT ProductName
# FROM Products as p
# LEFT JOIN Sales as s
# on p.ProductKey = s.ProductKey
# WHERE p.ProductKey NOT in(SELECT ProductKey FROM Sales);
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Contoso Home Theater System 5.1 Channel M1530 White',),
#  ('Contoso Washer & Dryer 21in E210 Green',),
#  ('Adventure Works Floor Lamp X1150 Black',),
#  ('Adventure Works Floor Lamp M2150 Black',),
#  ('Adventure Works Chandelier M6150 Black',),
#  ('Adventure Works Wall Lamp E3150 Silver',),
#  ('Adventure Works Desk Lamp E1300 Silver',),
#  ('Adventure Works Floor Lamp X1150 Grey',),
#  ('Adventure Works Wall Lamp E3150 Grey',),
#  ('Adventure Works Desk Lamp E1300 Grey',),
#  ('Adventure Works Desk Lamp E1200 Blue',),
#  ('WWI Floor Lamp X115 Black',),
#  ('WWI Wall Lamp E215 Black',),
#  ('WWI Wall Lamp E315 Silver',),
#  ('Proseware Wall Lamp E0215 Black',),
#  ('Proseware Desk Lamp E0120 Black',),
#  ('Proseware Chandelier M0815 White',),
#  ('Proseware Wall Lamp E0215 White',),
#  ('Proseware Floor Lamp M0215 Grey',),
#  ('Litware Chandelier M8015 White',),
#  ('Litware Chandelier M8015 Silver',),
# ...

# %% [markdown]
# **9. Currency Conversion for Orders. Write a query to show the total amount in USD, round to 2 decimal point for orders made in other currencies, using the Exchange Rates table to convert the prices.**

# %%
# %%sql
# --9.total amount in USD round to 2 decimal for orders made in other currencies
# SELECT
# round(sum(p.UnitPriceUSD * s.Quantity * e.Exchange),2)'total_orders_in_other_currencies($)'
# FROM Products as p
# LEFT JOIN Sales as s
# on p.ProductKey = s.ProductKey
# LEFT JOIN Exchange_Rates as e
# on e.Currency = s.CurrencyCode
# WHERE s.CurrencyCode != 'USD';
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(56594617451.23,)]

# %% [markdown]
# **10. Impact of Store Size on Sales Volume. Write a query to analyze whether larger stores (in terms of square meters) have higher sales volumes.**

# %%
# %%sql
# --10.impact of store size on sales volume
#
# SELECT sales.StoreKey, SquareMeters, sum(Quantity) as sales_volume
# FROM Sales
# LEFT JOIN Stores on Sales.StoreKey = Stores.StoreKey
# GROUP by SquareMeters
# ORDER by SquareMeters
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(0, None, 41311),
#  (13, 245, 592),
#  (18, 310, 607),
#  (12, 350, 2703),
#  (16, 385, 683),
#  (15, 400, 715),
#  (21, 560, 1351),
#  (1, 595, 871),
#  (2, 665, 61),
#  (66, 840, 3986),
#  (32, 910, 1474),
#  (29, 1000, 3144),
#  (31, 1085, 1396),
#  (47, 1120, 6613),
#  (43, 1190, 4258),
#  (28, 1200, 660),
#  (10, 1210, 3909),
#  (56, 1260, 8208),
#  (51, 1295, 6068),
#  (40, 1300, 6512),
#  (64, 1330, 4289),
#  (23, 1365, 3637),
#  (9, 1500, 4894),
#  (33, 1540, 5569),
#  (57, 1645, 4407),
#  (20, 1715, 1423),
#  (65, 1785, 4524),
#  (38, 1800, 3275),
#  (24, 1855, 2257),
#  (42, 1900, 3147),
#  (63, 2000, 50152),
#  (41, 2100, 10873),
#  (8, 2105, 4188)]

# %% [markdown]
# **11. Customer Segmentation by Purchase Behavior and Demographics. Write a query to segment customers into groups based on their purchase behaviors (e.g., total spend, number of orders) and demographics (e.g., state, gender).**

# %%
# %%sql
# --11.customer segmentation by Purchase behavior and demographics
#
# with customer_segmentation as(
# SELECT Gender,
#     State,
#     count(distinct OrderNumber)num_orders,
#     round(sum(UnitPriceUSD * Quantity))total_spend_USD
# FROM Customers as c
# LEFT JOIN Sales as s on c.CustomerKey = s.CustomerKey
# LEFT JOIN Products as p on s.ProductKey = p.ProductKey
# GROUP by State, Gender)
#     SELECT State,
#     Gender,
#     num_orders,
#     total_spend_USD,
#     CASE WHEN total_spend_USD >= 1000000000 THEN 'BILLION SPENDER'
#         WHEN total_spend_USD >= 1000000 THEN 'MILLION SPENDER'
#         WHEN total_spend_USD >= 100000 THEN 'HUNDRED THOUSAND SPENDER'
#         WHEN total_spend_USD >= 1000 THEN 'THOUSAND SPENDER'
#         WHEN total_spend_USD >= 100 THEN 'HUNDRED SPENDER'
#         WHEN total_spend_USD >= 10 THEN 'TENS SPENDER'
#         END AS purchase_behavior
#     FROM customer_segmentation
#     WHERE num_orders > 0
#     GROUP by State, Gender
#     LIMIT 200;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Aberdeen', 'Female', 4, 4703.0, 'THOUSAND SPENDER'),
#  ('Aberdeen', 'Male', 9, 15120.0, 'THOUSAND SPENDER'),
#  ('Aberdeenshire', 'Female', 42, 72772.0, 'THOUSAND SPENDER'),
#  ('Aberdeenshire', 'Male', 56, 74878.0, 'THOUSAND SPENDER'),
#  ('Agrigento', 'Female', 2, 10879.0, 'THOUSAND SPENDER'),
#  ('Alabama', 'Female', 105, 243319.0, 'HUNDRED THOUSAND SPENDER'),
#  ('Alabama', 'Male', 118, 210386.0, 'HUNDRED THOUSAND SPENDER'),
#  ('Alaska', 'Female', 35, 53989.0, 'THOUSAND SPENDER'),
#  ('Alaska', 'Male', 26, 50462.0, 'THOUSAND SPENDER'),
#  ('Alberta', 'Female', 197, 374967.0, 'HUNDRED THOUSAND SPENDER'),
#  ('Alberta', 'Male', 156, 305275.0, 'HUNDRED THOUSAND SPENDER'),
#  ('Alessandria', 'Female', 26, 56706.0, 'THOUSAND SPENDER'),
#  ('Alessandria', 'Male', 4, 15627.0, 'THOUSAND SPENDER'),
#  ('Allerdale', 'Female', 3, 234.0, 'HUNDRED SPENDER'),
#  ('Allerdale', 'Male', 10, 25482.0, 'THOUSAND SPENDER'),
# ...

# %% [markdown]
# **12. Ranking Stores by Sales Volume. Write a query to calculate the total sales volume for each store, then rank stores based on their sales volume.**

# %%
# %%sql
# --12. ranking stores by sales volume
#
# SELECT StoreKey,
# sum(Quantity) as sales_volume,
# RANK() over(ORDER by sum(Quantity) DESC)'rank'
# FROM Sales
# GROUP by StoreKey
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(0, 41311, 1),
#  (9, 4894, 2),
#  (55, 4826, 3),
#  (50, 4773, 4),
#  (61, 4771, 5),
#  (54, 4686, 6),
#  (59, 4674, 7),
#  (45, 4672, 8),
#  (44, 4581, 9),
#  (65, 4524, 10),
#  (57, 4407, 11),
#  (64, 4289, 12),
#  (43, 4258, 13),
#  (47, 4220, 14),
#  (8, 4188, 15),
#  (56, 4130, 16),
#  (51, 4095, 17),
#  (53, 4078, 18),
#  (48, 3995, 19),
#  (66, 3986, 20),
#  (10, 3909, 21),
#  (49, 3405, 22),
#  (39, 3284, 23),
#  (38, 3275, 24),
#  (40, 3260, 25),
#  (36, 3252, 26),
#  (30, 3182, 27),
#  (42, 3147, 28),
#  (29, 3144, 29),
#  (37, 3028, 30),
#  (5, 2944, 31),
#  (63, 2875, 32),
#  (22, 2409, 33),
#  (62, 2393, 34),
#  (27, 2327, 35),
#  (24, 2257, 36),
#  (23, 2172, 37),
#  (19, 1973, 38),
#  (6, 1923, 39),
#  (33, 1574, 40),
#  (32, 1474, 41),
#  (34, 1465, 42),
#  (20, 1423, 43),
#  (31, 1396, 44),
#  (41, 1379, 45),
#  (21, 1351, 46),
#  (4, 1286, 47),
#  (26, 968, 48),
#  (1, 871, 49),
#  (12, 748, 50),
#  (15, 715, 51),
# ...

# %% [markdown]
# **13. Running Total of Sales Over Time. Write a query to retrieve daily sales volumes, then calculate a running total of sales over time, ordered by date.**

# %%
# %%sql
# --13. Running Total of Sales Over Time
#
# WITH daily_sales as(
# 	SELECT OrderDate,
# 	sum(Quantity)sales_volume
# 	FROM Sales
# 	GROUP by OrderDate
# 	ORDER by OrderDate)
# SELECT OrderDate, sales_volume, sum(sales_volume) OVER(ORDER by OrderDate) as running_total
# FROM daily_sales
# ORDER by OrderDate
# LIMIT 100;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('2016-01-01', 88, 88),
#  ('2016-01-02', 66, 154),
#  ('2016-01-03', 56, 210),
#  ('2016-01-06', 94, 304),
#  ('2016-01-07', 98, 402),
#  ('2016-01-08', 33, 435),
#  ('2016-01-09', 105, 540),
#  ('2016-01-10', 128, 668),
#  ('2016-01-11', 44, 712),
#  ('2016-01-12', 76, 788),
#  ('2016-01-13', 108, 896),
#  ('2016-01-14', 71, 967),
#  ('2016-01-15', 40, 1007),
#  ('2016-01-16', 78, 1085),
#  ('2016-01-18', 18, 1103),
#  ('2016-01-19', 49, 1152),
#  ('2016-01-20', 56, 1208),
#  ('2016-01-21', 75, 1283),
#  ('2016-01-22', 72, 1355),
#  ('2016-01-23', 116, 1471),
#  ('2016-01-25', 33, 1504),
#  ('2016-01-26', 28, 1532),
#  ('2016-01-27', 89, 1621),
#  ('2016-01-28', 82, 1703),
#  ('2016-01-29', 57, 1760),
#  ('2016-01-30', 116, 1876),
#  ('2016-02-01', 252, 2128),
#  ('2016-02-02', 89, 2217),
#  ('2016-02-03', 105, 2322),
#  ('2016-02-05', 63, 2385),
#  ('2016-02-06', 99, 2484),
#  ('2016-02-07', 91, 2575),
#  ('2016-02-08', 17, 2592),
# ...

# %% [markdown]
# **14. Lifetime value (LTV) of customers by country. Write a query to calculate the lifetime value of each customer based on their country**
#
# ***Hint: The output should include the customer’s country, average LTV for that country, and rank the countries based on the average LTV in descending order.***

# %%
# %%sql
# --14. lifetime value of Customers by Country
#
# -- Step 1: Calculate the total revenue and order count for each customer
# WITH customer_revenue AS (
#     SELECT c.CustomerKey,
#     Country,
#         COUNT(*) AS order_count,
#         sum(UnitPriceUSD * Quantity)total_spend_USD,
#         MIN(OrderDate) AS first_purchase,
#         MAX(OrderDate) AS last_purchase
#     FROM Customers as c
#     LEFT JOIN Sales as s on c.CustomerKey = s.CustomerKey
#     LEFT JOIN Products as p on s.ProductKey = p.ProductKey
#     GROUP BY Country
# ),
# -- Step 2: Calculate the average order value (AOV)
# average_order_value AS (
#     SELECT CustomerKey,
#     Country,
#         total_spend_USD / order_count AS aov
#     FROM customer_revenue
# ),
#
# -- Step 3: Calculate the average order frequency (AOF) and customer lifespan
# order_frequency_and_lifespan AS (
#     SELECT
#         CustomerKey,
#         julianday(last_purchase) - julianday(first_purchase) / order_count AS aof,
#         julianday(last_purchase) - julianday(first_purchase) AS customer_lifespan
#     FROM customer_revenue
# ),
#
# -- Step 4: Combine all metrics to calculate the lifetime value (LTV)
# customer_lifetime_value AS (
#     SELECT
#         a.Country,
#         a.aov,
#         o.aof,
#         o.customer_lifespan,
#         a.aov * (o.customer_lifespan / o.aof) AS ltv
#     FROM average_order_value a
#     JOIN order_frequency_and_lifespan o
#     ON a.CustomerKey = o.CustomerKey
# )
#
# -- Step 5: Select the final LTV values
# SELECT
#     Country,
#     avg(ltv),
#     RANK() over(ORDER by avg(ltv) DESC)'rank'
#
# FROM customer_lifetime_value
# GROUP BY Country;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Italy', 0.7555558142305235, 1),
#  ('United States', 0.7526322077108988, 2),
#  ('Germany', 0.7458061147304644, 3),
#  ('United Kingdom', 0.7314779215071788, 4),
#  ('Canada', 0.7075364491958827, 5),
#  ('Netherlands', 0.7045657473344105, 6),
#  ('Australia', 0.6631026823461048, 7),
#  ('France', 0.6497448305582783, 8)]

# %% [markdown]
# **15. Customer Lifetime Value. Write a query to calculate the lifetime value of each customer based on the total amount they’ve spent.**

# %%
# %%sql
# --15. Customers lifetime value
# -- Calculate total purchase value per month
# WITH average_purchase AS (
#     SELECT CustomerKey,
#     strftime('%Y',OrderDate) || '-' || strftime('%m',OrderDate) AS period,
#     SUM(UnitPriceUSD * Quantity)total_purchase
#     FROM Sales
#     LEFT JOIN Products on
#     Sales.ProductKey = Products.ProductKey
#     GROUP BY CustomerKey, period
# )
# -- Calculate purchase frequency per month
# , purchase_frequency AS (
#     SELECT CustomerKey,
#     strftime('%Y',OrderDate) || '-' || strftime('%m',OrderDate) AS period,
#     COUNT(*) * 1.0 / (SELECT COUNT(DISTINCT CustomerKey) FROM Sales)purchase_frequency
#     FROM Sales
#     GROUP BY CustomerKey, period
# )
# -- Calculate average customer lifespan in months
# , average_lifespan AS (
#     SELECT CustomerKey,
#     (JULIANDAY(MAX(OrderDate)) - JULIANDAY(MIN(OrderDate))) / 30.0 AS avg_lifespan_months
#     FROM Sales
#     GROUP BY CustomerKey
# )
# -- Calculate CLV per month
# SELECT
#     DISTINCT c.Name,
#     a.period,
#     a.total_purchase * p.purchase_frequency * l.avg_lifespan_months customer_ltv
# FROM Customers c
# LEFT JOIN average_purchase a ON c.CustomerKey = a.CustomerKey
# LEFT JOIN purchase_frequency p ON c.CustomerKey = p.CustomerKey
# LEFT JOIN average_lifespan l ON c.CustomerKey = l.CustomerKey
# LIMIT 100;
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Lilly Harding', '2019-11', 0.0),
#  ('Madison Hull', '2018-01', 17.994414065786152),
#  ('Madison Hull', '2018-01', 26.991621098679225),
#  ('Madison Hull', '2018-01', 44.98603516446538),
#  ('Madison Hull', '2019-11', 4.190983427273492),
#  ('Madison Hull', '2019-11', 6.2864751409102375),
#  ('Madison Hull', '2019-11', 10.47745856818373),
#  ('Madison Hull', '2020-04', 4.074242057149267),
#  ('Madison Hull', '2020-04', 6.1113630857239),
#  ('Madison Hull', '2020-04', 10.185605142873166),
#  ('Claire Ferres', '2018-04', 0.40644401446958867),
#  ('Claire Ferres', '2018-04', 1.2193320434087658),
#  ('Claire Ferres', '2019-05', 0.6770765261770562),
#  ('Claire Ferres', '2019-05', 2.0312295785311685),
#  ('Jai Poltpalingada', None, None),
#  ('Aidan Pankhurst', '2018-06', 0.0),
#  ('Hayden Clegg', None, None),
#  ('Nicholas Caffyn', None, None),
#  ('Lincoln Jenks', None, None),
#  ('Isaac Israel', '2017-12', 0.0),
# ...

# %% [markdown]
# **16. Year-over-Year Growth in Sales per Category
# Write a query to calculate the total annual sales per product category for the current year and the previous year, and then use window functions to calculate the year-over-year growth percentage.**

# %%
# %%sql
# --16. Year over Year Growth in Sales per Category
# with yearly_sales as(
# 		SELECT Category,
# 		strftime('%Y', OrderDate)Year,
# 		round(sum(UnitPriceUSD * Quantity))Total_sales
# FROM Sales
# LEFT JOIN Products
# on Sales.ProductKey = Products.ProductKey
# GROUP by Category, Year)
# SELECT Category,
# 		Year,
# 		Total_sales,
# 		(Total_sales - lag(Total_sales) OVER(ORDER by Category)) * 100.0 / lag(Total_sales) OVER(ORDER by Category) as YoY_growth
# FROM yearly_sales
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Audio', '2016', 339348.0, None),
#  ('Audio', '2017', 472048.0, 39.10440020274173),
#  ('Audio', '2018', 798012.0, 69.05314713757923),
#  ('Audio', '2019', 1064198.0, 33.35614000791968),
#  ('Audio', '2020', 450770.0, -57.6422808537509),
#  ('Audio', '2021', 45252.0, -89.96117754065266),
#  ('Cameras and camcorders', '2016', 946180.0, 1990.9131088128702),
#  ('Cameras and camcorders', '2017', 721318.0, -23.765245513538652),
#  ('Cameras and camcorders', '2018', 1254126.0, 73.86589548576356),
#  ('Cameras and camcorders', '2019', 2260125.0, 80.21514584658958),
#  ('Cameras and camcorders', '2020', 1202300.0, -46.80382722194569),
#  ('Cameras and camcorders', '2021', 136119.0, -88.67844963819346),
#  ('Cell phones', '2016', 429497.0, 215.53052843467847),
#  ('Cell phones', '2017', 653411.0, 52.13400792089351),
#  ('Cell phones', '2018', 1372746.0, 110.08920878283347),
#  ('Cell phones', '2019', 2311958.0, 68.41848382730673),
# ...

# %% [markdown]
# **17. Customer’s Purchase Rank Within Store. Write a SQL query to find each customer’s purchase rank within the store they bought from, based on the total price of the order (quantity * unit price).**

# %%
# %%sql
# --17. Customer purchase rank within store
# SELECT s.CustomerKey,
# 		Name,
# 		round(sum(UnitPriceUSD * Quantity))total_spend_USD,
# 		RANK() over(ORDER by sum( UnitPriceUSD * Quantity) DESC)'rank'
# FROM Sales as s
# LEFT JOIN Products as p on s.ProductKey = p.ProductKey
# LEFT JOIN Customers as c on s.CustomerKey = c.CustomerKey
# GROUP by s.CustomerKey
# LIMIT 100
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(1702221, 'Matthew Flemming', 61872.0, 1),
#  (1884663, 'Karen Jones', 43518.0, 2),
#  (1969704, 'Zrina Topic', 42788.0, 3),
#  (535496, 'Stefanie Hartmann', 41522.0, 4),
#  (551036, 'Stephan Rothstein', 40557.0, 5),
#  (723572, 'Gaspare Trevisan', 40225.0, 6),
#  (262871, 'Roy Le', 38814.0, 7),
#  (1928466, 'Dennis Weissmuller', 38191.0, 8),
#  (1503831, 'Virgie Takacs', 37320.0, 9),
#  (1373561, 'Ollie Davis', 36817.0, 10),
#  (1087732, 'Michael Robertson', 36664.0, 11),
#  (2001755, 'Mie Huus', 36067.0, 12),
#  (1818102, 'Tyrone Lewis', 35806.0, 13),
#  (1579183, 'Paul Warren', 35780.0, 14),
#  (879649, 'Esin Holman', 35711.0, 15),
#  (714472, 'Bibiana Ferri', 34964.0, 16),
#  (1248847, 'Charles Collins', 34858.0, 17),
#  (1334387, 'Kyle Valentine', 34491.0, 18),
#  (1633967, 'Wayne Banks', 34484.0, 19),
#  (431461, 'Felix Beyer', 34344.0, 20),
#  (1049861, 'Daniel Walton', 34142.0, 21),
#  (1305082, 'David West', 34000.0, 22),
# ...

# %% [markdown]
# **18. Customer Retention Analysis. Perform a customer retention analysis to determine the percentage of customers who made repeat purchases within three months of their initial purchase.**
#
# ***Hint: The output should include a table with the customer demographics such as gender, age, location and calculated total customer count, retained customer count and the retention rate, in your analysis.***
# **Additionally, identify any trends or patterns in customer retention based on these demographics.**

# %%
# %%sql
# --18. Customer Retention Analysis
# WITH first_purchase AS ( -- Step 1: Calculate the first purchase date for each customer
#     SELECT CustomerKey, MIN(OrderDate) AS first_purchase_date
#     FROM Sales
#     GROUP BY CustomerKey)
# , repeat_purchases AS ( -- Step 2: Calculate repeat purchases within three months of the first purchase
#     SELECT s.CustomerKey, COUNT( DISTINCT s.OrderNumber) AS repeat_purchase_count
#     FROM Sales s
#     JOIN first_purchase fp ON s.CustomerKey = fp.CustomerKey
#     WHERE s.OrderDate BETWEEN fp.first_purchase_date AND DATE(fp.first_purchase_date, '+3 months')
#     AND s.OrderDate != fp.first_purchase_date
#     GROUP BY s.CustomerKey)
# -- Step 3: Calculate retention rates by demographics
# SELECT c.Gender, c.State || ', ' ||Country as location,
#     COUNT(c.CustomerKey) AS total_customers,
#     COUNT(rp.CustomerKey) AS retained_customers,
#     ROUND(COUNT(rp.CustomerKey) * 100.0 / COUNT(c.CustomerKey), 2) AS retention_rate
# FROM customers c
# LEFT JOIN repeat_purchases rp ON c.CustomerKey = rp.CustomerKey
# GROUP BY c.Gender, c.Country
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [('Female', 'South Australia, Australia', 721, 26, 3.61),
#  ('Female', 'Quebec, Canada', 755, 50, 6.62),
#  ('Female', 'Rh�ne-Alpes, France', 351, 11, 3.13),
#  ('Female', 'Rheinland-Pfalz, Germany', 734, 49, 6.68),
#  ('Female', 'Reggio Calabria, Italy', 319, 19, 5.96),
#  ('Female', 'Limburg, Netherlands', 345, 17, 4.93),
#  ('Female', 'Ceredigion, United Kingdom', 938, 68, 7.25),
#  ('Female', 'North Carolina, United States', 3355, 265, 7.9),
#  ('Male', 'South Australia, Australia', 699, 18, 2.58),
#  ('Male', 'British Columbia, Canada', 798, 47, 5.89),
#  ('Male', 'Guyane, France', 319, 8, 2.51),
#  ('Male', 'Brandenburg, Germany', 739, 56, 7.58),
#  ('Male', 'Benevento, Italy', 326, 23, 7.06),
#  ('Male', 'Utrecht, Netherlands', 388, 21, 5.41),
#  ('Male', 'Falkirk, United Kingdom', 1006, 60, 5.96),
#  ('Male', 'California, United States', 3473, 303, 8.72)]

# %% [markdown]
# **19. Optimize the product mix for each store location to maximize sales revenue.
# Analyze historical sales data to identify the top-selling products in each product category for each store.  Determine the optimal product assortment for each store based on sales performance, product popularity, and profit margins.**
#
# ***Hint: The output should include a table with the store key, category, product assortment (separated by ‘,’) and the quantities sold.***

# %%
# %%sql
# --19. optimize product mix for each store based on sales performance
# with store_volume as
# 	(SELECT StoreKey,
# 	Category,
# 	ProductName,
# 	sum(Quantity)quantities_sold
# FROM Sales
# LEFT JOIN Products on Sales.ProductKey = Products.ProductKey
# GROUP by StoreKey,Category,ProductName
# ORDER by StoreKey,Category, quantities_sold DESC)
# SELECT StoreKey,
# 		Category,
# 		group_concat(ProductName,', ')product_assortment,
# 		sum(quantities_sold)quantities_sold
# FROM store_volume
# GROUP by StoreKey, Category
# ORDER by StoreKey, Category,quantities_sold DESC
# LIMIT 50
# Out:
#  * sqlite:///sample_empovation_.db
# Done.
# [(0, 'Audio', 'WWI Wireless Bluetooth Stereo Headphones M270 Pink, NT Wireless Transmitter and Bluetooth Headphones M150 Silver, WWI 4GB Video Recording Pen X200 Re ... (5041 characters truncated) ... Flash MP3 Player E401 White, Contoso 32GB Video MP3 Player M3200 White, Contoso 32GB Video MP3 Player M3200 Orange, Contoso 4G MP3 Player E400 Silver', 4890),
#  (0, 'Cameras and camcorders', 'Contoso Carrying Case E312 Pink, A. Datum Consumer Digital Camera E100 Black, A. Datum All in One Digital Camera M200 Grey, A. Datum All in One Digit ... (15460 characters truncated) ...  Point Shoot Digital Camera M500 Silver, A. Datum Interchangeable lens Non-SLR Digital Camera X250 Grey, A. Datum Consumer Digital Camera M300 Orange', 3693),
# ...
